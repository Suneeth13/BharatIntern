# %%
pip install pandas numpy surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357254 sha256=cd79dd126d58e01a2bb8a9eae7d88ffa25220a19967239af370d5d68fa9bd046
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# ...

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate

# %%
# !wget http://files.grouplens.org/datasets/movielens/ml-100k/u.data -O u.data
# Out:
# --2024-05-20 06:39:34--  http://files.grouplens.org/datasets/movielens/ml-100k/u.data
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1979173 (1.9M)
# Saving to: ‘u.data’
#
# u.data              100%[===================>]   1.89M  10.3MB/s    in 0.2s
#
# 2024-05-20 06:39:34 (10.3 MB/s) - ‘u.data’ saved [1979173/1979173]

# %%
# Read the downloaded dataset into a DataFrame
df = pd.read_csv('u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])

# %%
# Specify the structure of the dataset
reader_config = Reader(line_format='user item rating timestamp', sep='\t')

# %%
# Convert the DataFrame to a Surprise Dataset
dataset = Dataset.load_from_df(df[['user_id', 'item_id', 'rating']], reader_config)

# %%
# Set up the Singular Value Decomposition (SVD) model
svd_model = SVD()

# %%
# Conduct 5-fold cross-validation to assess the model's performance
# Evaluation metrics: Root Mean Squared Error (RMSE) and Mean Absolute Error (MAE)
cross_val_results = cross_validate(svd_model, dataset, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9339  0.9413  0.9343  0.9478  0.9343  0.9383  0.0055
# MAE (testset)     0.7387  0.7418  0.7337  0.7448  0.7375  0.7393  0.0038
# Fit time          2.21    1.98    1.52    1.73    1.58    1.80    0.26
# Test time         0.12    0.26    0.11    0.19    0.12    0.16    0.06

# %%
# Display the outcomes of the cross-validation process
# This includes the mean and standard deviation of RMSE and MAE across the 5 folds
print("\nCross-validation summary:")
for metric, values in cross_val_results.items():
    print(f"{metric.capitalize()}: {np.mean(values):.3f} ± {np.std(values):.3f}")
# Out:
# Cross-validation summary:
# Test_rmse: 0.938 ± 0.005
# Test_mae: 0.739 ± 0.004
# Fit_time: 1.804 ± 0.257
# Test_time: 0.159 ± 0.058

# %%
'''To construct a movie recommendation system, an experiment was done with the SVD algorithm and MovieLens 100k Dataset that evaluated its performance utilizing 5-fold cross
validation with RMSE and MAE metrics. As is evident from results obtained, SVD algorithm performed well enough hence it can be used effectively for predicting users’ ratings;
while further observation revealed how much competitive consistency exists in the reported findings.” Based on our findings all over experimentations carried out,
such a conclusion has been reached in this regard concerning future improvement measures.'''
